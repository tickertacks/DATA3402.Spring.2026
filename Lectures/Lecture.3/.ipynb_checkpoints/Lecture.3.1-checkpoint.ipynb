# %% [markdown]
# Lecture ToDo:
# * Python environments
#
# * Chapters
#     * How computers work
#     * Structural Programming
#         * Plan out how you would modify to add king pieces to the checkers game.
# * Vibe Code
#     * Circuit to Logic Game
#     * Binary / Decimal Conversion Game
#     * Simple games
#         * Need prompt to keep syntax and style simple
#         * Use Checkers and Tic-tac-toe to define a style
#         *
# * Using the Primitives, Means of Combination, Means of Abstraction, ... (analogy to words, nouns, verbs, voice, tense, sentences, paragraphs, ...)
#     * Introduce C.
#         * Pointers in Lecture 3.
#         * Loops in Lecture 5.
#     * Introduce LISP during functional programming.
#         * Create a symbolic math example?
#         * Write LISP in Python?
#         * Connect it to Deep Learning frameworks.
#         * Introduce R when doing statistical?
#     * Introduce C++ when teaching OO.
#         * Connect to scientific software.
#             * Get contributions from colleagues
#                 * HEP Obviously
#                 * Medical Physics?
#                 * LIGO?
#                 * Industry?
#                 * Driverless cars
#                 * Robotic Control
#                 * State Machine
# * Exploratory Analysis?
#     * Basic Prob/Stat
#     * Random Variables, Distributions, and Populations
#         * Histogramming
#         * Summary statistics
#     * Visualization
#         * What type of distribution is it?
#         * Can I possibly identify different populations?
#                 *
# * Assignment / Exercise Ideas
#     * Make basic text games:
#         * Guess my number
#         * Hangman
#         * Snake
#             * Canvas
#         * Mine craft 2-D
#         * Jewel Grid
#         * Binary / Decimal Conversion
#         * Card Games with OO
#     *  Do pseudo design.
#         *
